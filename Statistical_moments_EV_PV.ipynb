# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

baseload = pd.read_csv('./data/Fluvius load profiles type 1 consumer/Type1consumerLoad3.csv', header=None)
# Rename columns to start numbering at 1
baseload.columns = range(1, baseload.shape[1] + 1)
# Adjust the index to start at 1
baseload.index = range(1, len(baseload) + 1)

chargingprofile = pd.read_csv('./data/yearly_charging_profile.csv', header=None)
# Drop the first row and column (headers)
chargingprofile = chargingprofile.drop(index=0, columns=0).reset_index(drop=True)
# Adjust the index to start at 1
chargingprofile.index = range(1, len(chargingprofile) + 1)
def min_max_normalize(df):
    return (df - df.min()) / (df.max() - df.min())
# Apply normalization
chargingprofile= min_max_normalize(chargingprofile)

solargen = pd.read_excel('./data/Belgium_solar_generation_probability_density.xlsx', sheet_name='Solar_profiles',header=None)
# Drop the first row and column (headers)
solargen = solargen.drop(index=0, columns=0).reset_index(drop=True)
# Adjust the index to start at 1
solargen.index = range(1, len(solargen) + 1)
# Drop the last column: 366 days -> 365 days
solargen = solargen.iloc[:, :-1]

netconsumption = baseload - solargen + chargingprofile

# %% [markdown]
# Statistical moment 1: Mean

# %%
chargingprofile_mean_year = chargingprofile.mean(axis=0)
baseload_mean_year = baseload.mean(axis=0)
solargen_mean_year = solargen.mean(axis=0)
netconsumption_mean_year = netconsumption.mean(axis=0)

fig, axs = plt.subplots(2, 2, figsize=(16, 10))  # 2 row, 2 columns
axs[0,0].plot(baseload_mean_year.index, baseload_mean_year)
axs[0,0].set_title('Baseload mean')
axs[0,0].set_xlabel('Days')
axs[0,0].set_ylabel('Mean Value')
axs[0,0].grid(axis='y')

axs[0,1].plot(solargen_mean_year.index, solargen_mean_year)
axs[0,1].set_title('Solargen mean')
axs[0,1].set_xlabel('Days')
axs[0,1].set_ylabel('Mean Value')
axs[0,1].grid(axis='y')

axs[1,0].plot(chargingprofile_mean_year.index, chargingprofile_mean_year)
axs[1,0].set_title('Charging profile mean')
axs[1,0].set_xlabel('Days')
axs[1,0].set_ylabel('Mean Value')
axs[1,0].grid(axis='y')

axs[1,1].plot(netconsumption_mean_year.index, netconsumption_mean_year, color='lightcoral')
axs[1,1].set_title('Net Consumption')
axs[1,1].set_xlabel('Days')
axs[1,1].set_ylabel('Mean Value')
axs[1,1].grid(axis='y')

# %%
chargingprofile_mean_day = chargingprofile.mean(axis=1)
baseload_mean_day = baseload.mean(axis=1)
solargen_mean_day = solargen.mean(axis=1)
netconsumption_mean_day = netconsumption.mean(axis=1)

fig, axs = plt.subplots(2, 2, figsize=(16, 10))  # 2 row, 2 columns
axs[0,0].plot(baseload_mean_day.index, baseload_mean_day)
axs[0,0].set_title('Baseload mean')
axs[0,0].set_xlabel('Days')
axs[0,0].set_ylabel('Mean Value')
axs[0,0].grid(axis='y')

axs[0,1].plot(solargen_mean_day.index, solargen_mean_day)
axs[0,1].set_title('Solargen mean')
axs[0,1].set_xlabel('Days')
axs[0,1].set_ylabel('Mean Value')
axs[0,1].grid(axis='y')

axs[1,0].plot(chargingprofile_mean_day.index, chargingprofile_mean_day)
axs[1,0].set_title('Charging profile mean')
axs[1,0].set_xlabel('Days')
axs[1,0].set_ylabel('Mean Value')
axs[1,0].grid(axis='y')

axs[1,1].plot(netconsumption_mean_day.index, netconsumption_mean_day, color='lightcoral')
axs[1,1].set_title('Net Consumption')
axs[1,1].set_xlabel('Days')
axs[1,1].set_ylabel('Mean Value')
axs[1,1].grid(axis='y')

# %% [markdown]
# Statistical moment 2: Variance

# %%
chargingprofile_var_year = chargingprofile.var(axis=0)
baseload_var_year = baseload.var(axis=0)
solargen_var_year = solargen.var(axis=0)
netconsumption_var_year = netconsumption.var(axis=0)

fig, axs = plt.subplots(2, 2, figsize=(16, 10))  # 2 row, 2 columns
axs[0,0].plot(baseload_var_year.index, baseload_var_year)
axs[0,0].set_title('Baseload var')
axs[0,0].set_xlabel('Days')
axs[0,0].set_ylabel('var Value')
axs[0,0].grid(axis='y')

axs[0,1].plot(solargen_var_year.index, solargen_var_year)
axs[0,1].set_title('Solargen var')
axs[0,1].set_xlabel('Days')
axs[0,1].set_ylabel('var Value')
axs[0,1].grid(axis='y')

axs[1,0].plot(chargingprofile_var_year.index, chargingprofile_var_year)
axs[1,0].set_title('Charging profile var')
axs[1,0].set_xlabel('Days')
axs[1,0].set_ylabel('var Value')
axs[1,0].grid(axis='y')

axs[1,1].plot(netconsumption_var_year.index, netconsumption_var_year, color='lightcoral')
axs[1,1].set_title('Net Consumption')
axs[1,1].set_xlabel('Days')
axs[1,1].set_ylabel('var Value')
axs[1,1].grid(axis='y')

# %%
chargingprofile_var_day = chargingprofile.var(axis=1)
baseload_var_day = baseload.var(axis=1)
solargen_var_day = solargen.var(axis=1)
netconsumption_var_day = netconsumption.var(axis=1)

fig, axs = plt.subplots(2, 2, figsize=(16, 10))  # 2 row, 2 columns
axs[0,0].plot(baseload_var_day.index, baseload_var_day)
axs[0,0].set_title('Baseload var')
axs[0,0].set_xlabel('Days')
axs[0,0].set_ylabel('var Value')
axs[0,0].grid(axis='y')

axs[0,1].plot(solargen_var_day.index, solargen_var_day)
axs[0,1].set_title('Solargen var')
axs[0,1].set_xlabel('Days')
axs[0,1].set_ylabel('var Value')
axs[0,1].grid(axis='y')

axs[1,0].plot(chargingprofile_var_day.index, chargingprofile_var_day)
axs[1,0].set_title('Charging profile var')
axs[1,0].set_xlabel('Days')
axs[1,0].set_ylabel('var Value')
axs[1,0].grid(axis='y')

axs[1,1].plot(netconsumption_var_day.index, netconsumption_var_day, color='lightcoral')
axs[1,1].set_title('Net Consumption')
axs[1,1].set_xlabel('Days')
axs[1,1].set_ylabel('var Value')
axs[1,1].grid(axis='y')

# %% [markdown]
# Statistical moment 3: Skewness

# %%
chargingprofile_skew_year = chargingprofile.skew(axis=0)
baseload_skew_year = baseload.skew(axis=0)
solargen_skew_year = solargen.skew(axis=0)
netconsumption_skew_year = netconsumption.skew(axis=0)

fig, axs = plt.subplots(2, 2, figsize=(16, 10))  # 2 row, 2 columns
axs[0,0].plot(baseload_skew_year.index, baseload_skew_year)
axs[0,0].set_title('Baseload skew')
axs[0,0].set_xlabel('Days')
axs[0,0].set_ylabel('skew Value')
axs[0,0].grid(axis='y')

axs[0,1].plot(solargen_skew_year.index, solargen_skew_year)
axs[0,1].set_title('Solargen skew')
axs[0,1].set_xlabel('Days')
axs[0,1].set_ylabel('skew Value')
axs[0,1].grid(axis='y')

axs[1,0].plot(chargingprofile_skew_year.index, chargingprofile_skew_year)
axs[1,0].set_title('Charging profile skew')
axs[1,0].set_xlabel('Days')
axs[1,0].set_ylabel('skew Value')
axs[1,0].grid(axis='y')

axs[1,1].plot(netconsumption_skew_year.index, netconsumption_skew_year, color='lightcoral')
axs[1,1].set_title('Net Consumption')
axs[1,1].set_xlabel('Days')
axs[1,1].set_ylabel('var Value')
axs[1,1].grid(axis='y')

# %%
chargingprofile_skew_day = chargingprofile.skew(axis=1)
baseload_skew_day = baseload.skew(axis=1)
solargen_skew_day = solargen.skew(axis=1)
netconsumption_skew_day = netconsumption.skew(axis=1)

fig, axs = plt.subplots(2, 2, figsize=(16, 10))  # 2 row, 2 columns
axs[0,0].plot(baseload_skew_day.index, baseload_skew_day)
axs[0,0].set_title('Baseload skew')
axs[0,0].set_xlabel('Days')
axs[0,0].set_ylabel('skew Value')
axs[0,0].grid(axis='y')

axs[0,1].plot(solargen_skew_day.index, solargen_skew_day)
axs[0,1].set_title('Solargen skew')
axs[0,1].set_xlabel('Days')
axs[0,1].set_ylabel('skew Value')
axs[0,1].grid(axis='y')

axs[1,0].plot(chargingprofile_skew_day.index, chargingprofile_skew_day)
axs[1,0].set_title('Charging profile skew')
axs[1,0].set_xlabel('Days')
axs[1,0].set_ylabel('skew Value')
axs[1,0].grid(axis='y')

axs[1,1].plot(netconsumption_skew_day.index, netconsumption_skew_day, color='lightcoral')
axs[1,1].set_title('Net Consumption')
axs[1,1].set_xlabel('Days')
axs[1,1].set_ylabel('var Value')
axs[1,1].grid(axis='y')

# %% [markdown]
# Statistical moment 4: Kurtosis

# %%
chargingprofile_kurt_year = chargingprofile.kurt(axis=0)
baseload_kurt_year = baseload.kurt(axis=0)
solargen_kurt_year = solargen.kurt(axis=0)
netconsumption_kurt_year = netconsumption.kurt(axis=0)

fig, axs = plt.subplots(2, 2, figsize=(16, 10))  # 2 row, 2 columns
axs[0,0].plot(baseload_kurt_year.index, baseload_kurt_year)
axs[0,0].set_title('Baseload kurt')
axs[0,0].set_xlabel('Days')
axs[0,0].set_ylabel('kurt Value')
axs[0,0].grid(axis='y')

axs[0,1].plot(solargen_kurt_year.index, solargen_kurt_year)
axs[0,1].set_title('Solargen kurt')
axs[0,1].set_xlabel('Days')
axs[0,1].set_ylabel('kurt Value')
axs[0,1].grid(axis='y')

axs[1,0].plot(chargingprofile_kurt_year.index, chargingprofile_kurt_year)
axs[1,0].set_title('Charging profile kurt')
axs[1,0].set_xlabel('Days')
axs[1,0].set_ylabel('kurt Value')
axs[1,0].grid(axis='y')

axs[1,1].plot(netconsumption_kurt_year.index, netconsumption_kurt_year, color='lightcoral')
axs[1,1].set_title('Net Consumption')
axs[1,1].set_xlabel('Days')
axs[1,1].set_ylabel('var Value')
axs[1,1].grid(axis='y')

# %%
chargingprofile_kurt_day = chargingprofile.kurt(axis=1)
baseload_kurt_day = baseload.kurt(axis=1)
solargen_kurt_day = solargen.kurt(axis=1)
netconsumption_kurt_day = netconsumption.kurt(axis=1)

fig, axs = plt.subplots(2, 2, figsize=(16, 10))  # 2 row, 2 columns
axs[0,0].plot(baseload_kurt_day.index, baseload_kurt_day)
axs[0,0].set_title('Baseload kurt')
axs[0,0].set_xlabel('Days')
axs[0,0].set_ylabel('kurt Value')
axs[0,0].grid(axis='y')

axs[0,1].plot(solargen_kurt_day.index, solargen_kurt_day)
axs[0,1].set_title('Solargen kurt')
axs[0,1].set_xlabel('Days')
axs[0,1].set_ylabel('kurt Value')
axs[0,1].grid(axis='y')

axs[1,0].plot(chargingprofile_kurt_day.index, chargingprofile_kurt_day)
axs[1,0].set_title('Charging profile kurt')
axs[1,0].set_xlabel('Days')
axs[1,0].set_ylabel('kurt Value')
axs[1,0].grid(axis='y')

axs[1,1].plot(netconsumption_kurt_day.index, netconsumption_kurt_day, color='lightcoral')
axs[1,1].set_title('Net Consumption')
axs[1,1].set_xlabel('Days')
axs[1,1].set_ylabel('var Value')
axs[1,1].grid(axis='y')
